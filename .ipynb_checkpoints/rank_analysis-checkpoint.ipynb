# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('fivethirtyeight')

from os import listdir
from os.path import isfile, join

import re

# %%
def removeExtension(file_name):
    idx = -1
    for i, c in enumerate(file_name):
        if c == '.':
            idx = i
            break
    if idx >= 0:
        return file_name[:idx]
    return file_name

# %%
SUBMISSIONS_DIR = './single_submissions/'
MATCH_RESULTS_DIR = './final_match_results/'

# %%
files = sorted([f for f in listdir(SUBMISSIONS_DIR) if isfile(join(SUBMISSIONS_DIR, f)) and f[-1] != 'c'])
names = sorted([removeExtension(f) for f in files])

teams = list(zip(files, names))

# %%
match_results_df = pd.DataFrame(columns=['Team', 'Opponent', 'Wins', 'Losses', 'Ties', 'Invalid'])

# %%
def process_raw_outcome(outcome):
    return outcome.replace('\n', '')

for i in range(len(teams)):
    for j in range(i + 1, len(teams)):
        if i == j:
            continue
        
        file_a, name_a = teams[i]
        file_b, name_b = teams[j]
        
        # Get match results for team a vs team b
        match_data_file_name = name_a + '_vs_' + name_b + '.dat'
        try:
            match_data_file = open(join(MATCH_RESULTS_DIR, match_data_file_name), 'r')
        except FileNotFoundError:
            continue
        outcomes = [process_raw_outcome(l) for l in match_data_file]
        outcomes = outcomes[:15]
        match_data_file.close()
        
        # Get DataFrame props
        num_rows, num_cols = match_results_df.shape
        
        # Insert row if doesn't exist or reset row
        index_a, index_b = -1, -1
        for k in range(num_rows):
            row = match_results_df.loc[k]
            if row.Team == name_a and row.Opponent == name_b:
                index_a = k
            if row.Team == name_b and row.Opponent == name_a:
                index_b = k
        if index_a == -1 and index_b == -1:
            index_a, index_b = num_rows, num_rows + 1
        elif index_a == -1:
            index_a = num_rows
        elif index_b == -1:
            index_b == num_rows
        
        win, loss, tied, invalid = 0, 0, 0, 0
        for outcome in outcomes:
            if outcome == name_a:
                win += 1
            elif outcome == name_b:
                loss += 1
            elif outcome == 'tied':
                tied += 1
            elif outcome == 'invalid':
                invalid += 1
            else:
                raise Error('Invalid match outcome')
        match_results_df.loc[index_a] = [name_a, name_b, win, loss, tied, invalid]
        match_results_df.loc[index_b] = [name_b, name_a, loss, win, tied, invalid]

# %%
match_results_df.shape
# Out:
# (462, 6)

# %%
match_results_df.head()
# Out:
#                          Team                    Opponent Wins Losses Ties  \
# 0            PacBot_Kevin_Cao     baselineTeam2_Rachel_Li    5     10    0
# 1     baselineTeam2_Rachel_Li            PacBot_Kevin_Cao   10      5    0
# 2            PacBot_Kevin_Cao  baselineTeam2_Raghav_Anand    9      6    0
# 3  baselineTeam2_Raghav_Anand            PacBot_Kevin_Cao    6      9    0
# 4            PacBot_Kevin_Cao       cleverTeam_Dylan_Rowe   10      5    0
#
#   Invalid
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
match_results_df[match_results_df['Invalid'] > 10].shape
# Out:
# (0, 6)

# %% [markdown]
# # Invalid Submissions

# %%
invalid_dict = dict(zip(names, [0] * len(names)))
for file, name in teams:
    invalids = match_results_df[(match_results_df['Invalid'] > 4) & (match_results_df['Team'] == name)].shape[0]
    invalid_dict[name] += invalids
    
INVALID_THRESH = 5
invalid_list = [name for name in names if invalid_dict[name] > INVALID_THRESH]
invalid_list
# Out:
# []

# %%
plt.hist(list(invalid_dict.values()), bins=np.arange(0, 20, 2))
plt.show()

# %% [markdown]
# # Elo

# %%
elo_dict = dict(zip(names, [1500] * len(names)))

# %%
match_results_df['margin'] = match_results_df.Wins - match_results_df.Losses

# %%
def elo_pred(elo1, elo2):
    return(1. / (10. ** (-(elo1 - elo2) / 400.) + 1.))

def expected_margin(elo_diff):
    return((7.5 + 0.006 * elo_diff))

def elo_update(w_elo, l_elo, margin, K=20):
    elo_diff = w_elo - l_elo
    pred = elo_pred(w_elo, l_elo)
    mult = ((margin + 3.) ** 0.8) / expected_margin(elo_diff)
    update = K * mult * (1 - pred)
    return(pred, update)

# %%
sample_match_results_df = match_results_df.sample(match_results_df.shape[0])

# %%
preds = []
w_elo = []
l_elo = []

# Loop over all rows of the games dataframe
for row in sample_match_results_df.itertuples():
    # Get key data from current row
    w = row.Team
    l = row.Opponent
    margin = row.margin
    
    # Get elo updates as a result of the game
    pred, update = elo_update(elo_dict[w],
                              elo_dict[l], 
                              margin)
    elo_dict[w] += update
    elo_dict[l] -= update
    
    # Save prediction and new Elos for each round
    preds.append(pred)
    w_elo.append(elo_dict[w])
    l_elo.append(elo_dict[l])

# %%
win_elo = []
for w in w_elo:
    if isinstance(w, complex):
        win_elo.append(w.real)
    else:
        win_elo.append(w)
        
loss_elo = []
for l in l_elo:
    if isinstance(l, complex):
        loss_elo.append(l.real)
    else:
        loss_elo.append(l)

# %%
sample_match_results_df['w_elo'] = win_elo
sample_match_results_df['l_elo'] = loss_elo

# %%
sample_match_results_df.tail(10)
# Out:
#                                    Team                          Opponent  \
# 98           baselineTeam2_Raghav_Anand              myTeam_Colin_K_Lai_1
# 299                 myTeam_Shreya_Sahoo       myTeam_ANTON_SHELBY_OYUNG_1
# 82           baselineTeam2_Raghav_Anand             cleverTeam_Dylan_Rowe
# 123             myTeam2_SEAN_ADAM_MEDIN             cleverTeam_Dylan_Rowe
# 175             myTeam_Joshua_Yurtsever  coolTeam_SONTHAYA_VISUTHIKRAISEE
# 268                   myTeam_ANISH_SAHA                myTeam_Laura_Smith
# 348             myTeam_Christina_Baek_1                   myTeam_Xing_Jin
# 378                 myTeam_DONGMIN_KANG                myTeam_Laura_Smith
# 20                     PacBot_Kevin_Cao              myTeam_Colin_K_Lai_1
# 248  myTeam3_4foodNum_ALI_KHALEEL_AHMED                   myTeam_Xing_Jin
#
#     Wins Losses Ties Invalid margin        w_elo        l_elo
# 98    10      4    1       0      6  1485.203249  1488.956511
# 299    0      0   15       0      0  1337.144352  1390.606952
# 82     5      9    1       0     -4  1484.284571  1426.026035
# 123   14      1    0       0     13  1723.265501  1423.677020
# 175    4      5    6       0     -1  1549.221254  1526.337885
# 268    0      8    7       0     -8  1363.776085  1621.372759
# 348    9      0    6       0      9  1720.642413  1526.433248
# 378    1     12    2       0    -11  1332.180725  1631.892350
# 20    10      5    0       0      5  1436.285494  1480.270924
# 248    7      3    5       0      4  1689.363182  1523.370526

# %%
final_elo_dict = dict(zip(names, [1500] * len(names)))

# %%
for row in sample_match_results_df.itertuples():
    final_elo_dict[row.Team] = row.w_elo
    final_elo_dict[row.Opponent] = row.l_elo

# %%
rankings = zip(final_elo_dict.keys(), final_elo_dict.values())
rankings = [r for r in rankings if r[0] not in invalid_list]
rankings = sorted(list(rankings), key=lambda x: -x[1])
place = 1
for name, elo in rankings:
    print('%d.' %place, name, '(%.3f)' % elo)
    place += 1
# Out:
# 1. myTeam2_SEAN_ADAM_MEDIN (1723.266)
# 2. myTeam_Christina_Baek_1 (1720.642)
# 3. myTeam3_4foodNum_ALI_KHALEEL_AHMED (1689.363)
# 4. myTeam_Laura_Smith (1631.892)
# 5. myTeam_SHARABESH_RAMESH (1621.550)
# 6. myTeam_Swapnil_Das_1 (1549.871)
# 7. myTeam_Joshua_Yurtsever (1549.221)
# 8. myTeam_Benjamin_Carlson_1 (1539.035)
# 9. coolTeam_SONTHAYA_VISUTHIKRAISEE (1526.338)
# 10. myTeam_Xing_Jin (1523.371)
# 11. myTeam_Julia_Luo (1486.441)
# 12. baselineTeam2_Raghav_Anand (1484.285)
# 13. myTeam_Colin_K_Lai_1 (1480.271)
# 14. baselineTeam2_Rachel_Li (1445.462)
# 15. PacBot_Kevin_Cao (1436.285)
# 16. cleverTeam_Dylan_Rowe (1423.677)
# 17. myTeam_ANTON_SHELBY_OYUNG_1 (1390.607)
# 18. veryCleverTeam_Gao_Xian_Peh (1373.037)
# 19. myTeam_Jesse_Zhang_Zhang (1372.284)
# 20. myTeam_ANISH_SAHA (1363.776)
# 21. myTeam_Shreya_Sahoo (1337.144)
# 22. myTeam_DONGMIN_KANG (1332.181)

# %% [markdown]
# # Manual Investigation

# %%
match_results_df[match_results_df['Team'] == 'myTeam2_SEAN_ADAM_MEDIN']
# Out:
#                         Team                            Opponent Wins Losses  \
# 9    myTeam2_SEAN_ADAM_MEDIN                    PacBot_Kevin_Cao   14      1
# 49   myTeam2_SEAN_ADAM_MEDIN             baselineTeam2_Rachel_Li   11      0
# 87   myTeam2_SEAN_ADAM_MEDIN          baselineTeam2_Raghav_Anand    8      0
# 123  myTeam2_SEAN_ADAM_MEDIN               cleverTeam_Dylan_Rowe   14      1
# 157  myTeam2_SEAN_ADAM_MEDIN    coolTeam_SONTHAYA_VISUTHIKRAISEE   14      0
# 190  myTeam2_SEAN_ADAM_MEDIN  myTeam3_4foodNum_ALI_KHALEEL_AHMED    8      1
# 192  myTeam2_SEAN_ADAM_MEDIN                   myTeam_ANISH_SAHA   14      1
# 194  myTeam2_SEAN_ADAM_MEDIN         myTeam_ANTON_SHELBY_OYUNG_1   15      0
# 196  myTeam2_SEAN_ADAM_MEDIN           myTeam_Benjamin_Carlson_1   11      0
# 198  myTeam2_SEAN_ADAM_MEDIN             myTeam_Christina_Baek_1    3      4
# 200  myTeam2_SEAN_ADAM_MEDIN                myTeam_Colin_K_Lai_1   15      0
# 202  myTeam2_SEAN_ADAM_MEDIN                 myTeam_DONGMIN_KANG   12      1
# 204  myTeam2_SEAN_ADAM_MEDIN            myTeam_Jesse_Zhang_Zhang   12      2
# 206  myTeam2_SEAN_ADAM_MEDIN             myTeam_Joshua_Yurtsever    1      1
# 208  myTeam2_SEAN_ADAM_MEDIN                    myTeam_Julia_Luo    0      0
# 210  myTeam2_SEAN_ADAM_MEDIN                  myTeam_Laura_Smith    7      5
# 212  myTeam2_SEAN_ADAM_MEDIN             myTeam_SHARABESH_RAMESH    8      5
# 214  myTeam2_SEAN_ADAM_MEDIN                 myTeam_Shreya_Sahoo   10      0
# 216  myTeam2_SEAN_ADAM_MEDIN                myTeam_Swapnil_Das_1    7      1
# 218  myTeam2_SEAN_ADAM_MEDIN                     myTeam_Xing_Jin    5      1
# 220  myTeam2_SEAN_ADAM_MEDIN         veryCleverTeam_Gao_Xian_Peh   15      0
#
#     Ties Invalid margin        w_elo        l_elo
# 9      0       0     13  1518.703972  1492.796535
# 49     4       0     11  1534.475962  1480.918982
# 87     7       0      8  1546.188778  1470.291665
# 123    0       0     13  1563.836311  1497.053899
# 157    1       0     14  1581.767778  1477.171142
# 190    6       0      7  1588.774362  1527.586578
# 192    0       0     13  1600.976141  1488.648083
# 194    0       0     15  1618.535587  1483.775425
# 196    4       0     11  1636.719529  1508.258120
# 198    8       0     -1  1646.388325  1566.389481
# 200    0       0     15  1647.056057  1453.868330
# 202    2       0     11  1664.412273  1463.467800
# 204    1       0     10  1678.179546  1487.119400
# 206   13       0      0  1687.811049  1526.605345
# 208   15       0      0  1683.889491  1494.464791
# 210    3       0      2  1680.898356  1539.891364
# 212    2       0      3  1681.875418  1537.335252
# 214    5       0     10  1685.124145  1438.347596
# 216    7       0      6  1697.745178  1519.093686
# 218    9       0      4  1704.162389  1500.378586
# 220    0       0     15  1710.246986  1468.817288

# %%
match_results_df[match_results_df['Team'] == 'myTeam_Christina_Baek_1']
# Out:
#                         Team                            Opponent Wins Losses  \
# 19   myTeam_Christina_Baek_1                    PacBot_Kevin_Cao   14      1
# 59   myTeam_Christina_Baek_1             baselineTeam2_Rachel_Li    7      1
# 97   myTeam_Christina_Baek_1          baselineTeam2_Raghav_Anand   13      0
# 133  myTeam_Christina_Baek_1               cleverTeam_Dylan_Rowe   10      3
# 167  myTeam_Christina_Baek_1    coolTeam_SONTHAYA_VISUTHIKRAISEE   11      1
# 199  myTeam_Christina_Baek_1             myTeam2_SEAN_ADAM_MEDIN    4      3
# 229  myTeam_Christina_Baek_1  myTeam3_4foodNum_ALI_KHALEEL_AHMED    1      6
# 257  myTeam_Christina_Baek_1                   myTeam_ANISH_SAHA   12      1
# 283  myTeam_Christina_Baek_1         myTeam_ANTON_SHELBY_OYUNG_1   11      0
# 307  myTeam_Christina_Baek_1           myTeam_Benjamin_Carlson_1   10      1
# 330  myTeam_Christina_Baek_1                myTeam_Colin_K_Lai_1   13      0
# 332  myTeam_Christina_Baek_1                 myTeam_DONGMIN_KANG   14      0
# 334  myTeam_Christina_Baek_1            myTeam_Jesse_Zhang_Zhang   11      0
# 336  myTeam_Christina_Baek_1             myTeam_Joshua_Yurtsever    4      3
# 338  myTeam_Christina_Baek_1                    myTeam_Julia_Luo    2      1
# 340  myTeam_Christina_Baek_1                  myTeam_Laura_Smith    8      3
# 342  myTeam_Christina_Baek_1             myTeam_SHARABESH_RAMESH   11      0
# 344  myTeam_Christina_Baek_1                 myTeam_Shreya_Sahoo    5      0
# 346  myTeam_Christina_Baek_1                myTeam_Swapnil_Das_1    9      2
# 348  myTeam_Christina_Baek_1                     myTeam_Xing_Jin    9      0
# 350  myTeam_Christina_Baek_1         veryCleverTeam_Gao_Xian_Peh    8      0
#
#     Ties Invalid margin        w_elo        l_elo
# 19     0       0     13  1517.532984  1446.143796
# 59     7       0      6  1527.067503  1475.138946
# 97     2       0     13  1544.665705  1472.609329
# 133    2       0      7  1554.449761  1443.908978
# 167    3       0     10  1568.095332  1473.764792
# 199    8       0      1  1571.680225  1641.097582
# 229    8       0     -5  1562.742009  1583.832032
# 257    2       0     11  1576.727804  1432.680007
# 283    4       0     11  1590.451281  1431.723466
# 307    4       0      9  1602.596647  1496.504425
# 330    2       0     13  1609.074302  1449.942241
# 332    1       0     14  1624.512955  1420.801838
# 334    4       0     11  1641.182193  1447.283903
# 336    8       0      1  1652.714575  1539.417647
# 338   12       0      1  1651.354079  1488.563900
# 340    4       0      5  1652.432357  1554.981142
# 342    4       0     11  1662.141653  1549.129653
# 344   10       0      5  1671.594530  1403.492634
# 346    4       0      7  1679.413170  1524.652975
# 348    6       0      9  1688.261834  1494.633977
# 350    7       0      8  1697.752899  1428.904233

# %%
match_results_df[match_results_df['Team'] == 'myTeam3_4foodNum_ALI_KHALEEL_AHMED']
# Out:
#                                    Team                          Opponent  \
# 11   myTeam3_4foodNum_ALI_KHALEEL_AHMED                  PacBot_Kevin_Cao
# 51   myTeam3_4foodNum_ALI_KHALEEL_AHMED           baselineTeam2_Rachel_Li
# 89   myTeam3_4foodNum_ALI_KHALEEL_AHMED        baselineTeam2_Raghav_Anand
# 125  myTeam3_4foodNum_ALI_KHALEEL_AHMED             cleverTeam_Dylan_Rowe
# 159  myTeam3_4foodNum_ALI_KHALEEL_AHMED  coolTeam_SONTHAYA_VISUTHIKRAISEE
# 191  myTeam3_4foodNum_ALI_KHALEEL_AHMED           myTeam2_SEAN_ADAM_MEDIN
# 222  myTeam3_4foodNum_ALI_KHALEEL_AHMED                 myTeam_ANISH_SAHA
# 224  myTeam3_4foodNum_ALI_KHALEEL_AHMED       myTeam_ANTON_SHELBY_OYUNG_1
# 226  myTeam3_4foodNum_ALI_KHALEEL_AHMED         myTeam_Benjamin_Carlson_1
# 228  myTeam3_4foodNum_ALI_KHALEEL_AHMED           myTeam_Christina_Baek_1
# 230  myTeam3_4foodNum_ALI_KHALEEL_AHMED              myTeam_Colin_K_Lai_1
# 232  myTeam3_4foodNum_ALI_KHALEEL_AHMED               myTeam_DONGMIN_KANG
# 234  myTeam3_4foodNum_ALI_KHALEEL_AHMED          myTeam_Jesse_Zhang_Zhang
# 236  myTeam3_4foodNum_ALI_KHALEEL_AHMED           myTeam_Joshua_Yurtsever
# 238  myTeam3_4foodNum_ALI_KHALEEL_AHMED                  myTeam_Julia_Luo
# 240  myTeam3_4foodNum_ALI_KHALEEL_AHMED                myTeam_Laura_Smith
# 242  myTeam3_4foodNum_ALI_KHALEEL_AHMED           myTeam_SHARABESH_RAMESH
# 244  myTeam3_4foodNum_ALI_KHALEEL_AHMED               myTeam_Shreya_Sahoo
# 246  myTeam3_4foodNum_ALI_KHALEEL_AHMED              myTeam_Swapnil_Das_1
# 248  myTeam3_4foodNum_ALI_KHALEEL_AHMED                   myTeam_Xing_Jin
# 250  myTeam3_4foodNum_ALI_KHALEEL_AHMED       veryCleverTeam_Gao_Xian_Peh
#
#     Wins Losses Ties Invalid margin        w_elo        l_elo
# 11     8      2    5       0      6  1510.017572  1482.778962
# 51     8      3    4       0      5  1518.277019  1472.659535
# 89     2      8    5       0     -6  1506.769124  1481.799560
# 125   11      1    3       0     10  1521.617759  1482.205265
# 159   11      2    2       0      9  1534.593162  1464.195739
# 191    1      8    6       0     -7  1523.676625  1592.684315
# 222   14      0    1       0     14  1534.513098  1468.459287
# 224   11      0    4       0     11  1551.797235  1464.090835
# 226   12      1    2       0     11  1567.850385  1491.561018
# 228    6      1    8       0      5  1581.848051  1564.725990
# 230   12      1    2       0     11  1589.783878  1435.127498
# 232   12      0    3       0     12  1604.540497  1447.967232
# 234   12      1    2       0     11  1620.062725  1472.907764
# 236    8      3    4       0      5  1633.044613  1527.158005
# 238    5      0   10       0      5  1639.435658  1496.191968
# 240    7      3    5       0      4  1646.318073  1537.791212
# 242   10      3    2       0      7  1653.054419  1532.025493
# 244    8      0    7       0      8  1660.631408  1426.187407
# 246    7      7    1       0      0  1669.094076  1513.514643
# 248    7      3    5       0      4  1666.917282  1495.631634
# 250   11      0    4       0     11  1672.581692  1451.040550

# %%
match_results_df[match_results_df['Team'] == 'veryCleverTeam_Gao_Xian_Peh']
# Out:
#                             Team                            Opponent Wins  \
# 41   veryCleverTeam_Gao_Xian_Peh                    PacBot_Kevin_Cao    3
# 81   veryCleverTeam_Gao_Xian_Peh             baselineTeam2_Rachel_Li    0
# 119  veryCleverTeam_Gao_Xian_Peh          baselineTeam2_Raghav_Anand    2
# 155  veryCleverTeam_Gao_Xian_Peh               cleverTeam_Dylan_Rowe    1
# 189  veryCleverTeam_Gao_Xian_Peh    coolTeam_SONTHAYA_VISUTHIKRAISEE    0
# 221  veryCleverTeam_Gao_Xian_Peh             myTeam2_SEAN_ADAM_MEDIN    0
# 251  veryCleverTeam_Gao_Xian_Peh  myTeam3_4foodNum_ALI_KHALEEL_AHMED    0
# 279  veryCleverTeam_Gao_Xian_Peh                   myTeam_ANISH_SAHA    0
# 305  veryCleverTeam_Gao_Xian_Peh         myTeam_ANTON_SHELBY_OYUNG_1    1
# 329  veryCleverTeam_Gao_Xian_Peh           myTeam_Benjamin_Carlson_1    0
# 351  veryCleverTeam_Gao_Xian_Peh             myTeam_Christina_Baek_1    0
# 371  veryCleverTeam_Gao_Xian_Peh                myTeam_Colin_K_Lai_1    3
# 389  veryCleverTeam_Gao_Xian_Peh                 myTeam_DONGMIN_KANG    1
# 405  veryCleverTeam_Gao_Xian_Peh            myTeam_Jesse_Zhang_Zhang    1
# 419  veryCleverTeam_Gao_Xian_Peh             myTeam_Joshua_Yurtsever    0
# 431  veryCleverTeam_Gao_Xian_Peh                    myTeam_Julia_Luo    0
# 441  veryCleverTeam_Gao_Xian_Peh                  myTeam_Laura_Smith    0
# 449  veryCleverTeam_Gao_Xian_Peh             myTeam_SHARABESH_RAMESH    0
# 455  veryCleverTeam_Gao_Xian_Peh                 myTeam_Shreya_Sahoo    0
# 459  veryCleverTeam_Gao_Xian_Peh                myTeam_Swapnil_Das_1    1
# 461  veryCleverTeam_Gao_Xian_Peh                     myTeam_Xing_Jin    0
#
#     Losses Ties Invalid margin        w_elo        l_elo
# 41       2   10       0      1  1500.368857  1437.635804
# 81       5   10       0     -5  1489.901740  1443.475128
# 119      7    6       0     -5  1480.805976  1494.742485
# 155      1   13       0      0  1479.579023  1426.362924
# 189      4   11       0     -4  1473.181450  1542.643471
# 221     15    0       0    -15  1455.065612  1723.998662
# 251     11    4       0    -11  1441.431233  1682.191009
# 279      1   14       0     -1  1438.236934  1378.887199
# 305      1   13       0      0  1436.979245  1382.470341
# 329      4   11       0     -4  1431.262815  1537.196124
# 351      8    7       0     -8  1421.869001  1704.788131
# 371     12    0       0     -9  1408.577641  1492.725999
# 389      0   14       0      1  1408.597710  1331.159548
# 405      0   14       0      1  1409.758377  1380.251346
# 419      4   11       0     -4  1404.668412  1548.742063
# 431      0   15       0      0  1406.590020  1481.832988
# 441      9    6       0     -9  1395.460494  1623.848793
# 449     10    5       0    -10  1383.312492  1621.843125
# 455      0   15       0      0  1382.276668  1336.863266
# 459     12    2       0    -11  1368.233911  1546.341092
# 461      3   12       0     -3  1365.288321  1516.712181
