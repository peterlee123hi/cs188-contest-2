# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('fivethirtyeight')

from os import listdir
from os.path import isfile, join

import re

# %%
def removeExtension(file_name):
    idx = -1
    for i, c in enumerate(file_name):
        if c == '.':
            idx = i
            break
    if idx >= 0:
        return file_name[:idx]
    return file_name

# %%
SUBMISSIONS_DIR = './submissions/'
MATCH_RESULTS_DIR = './match_results/'

# %%
files = sorted([f for f in listdir(SUBMISSIONS_DIR) if isfile(join(SUBMISSIONS_DIR, f)) and f[-1] != 'c'])
names = sorted([removeExtension(f) for f in files])

teams = list(zip(files, names))

# %%
match_results_df = pd.DataFrame(columns=['Team', 'Opponent', 'Wins', 'Losses', 'Ties', 'Invalid'])

# %%
def process_raw_outcome(outcome):
    return outcome.replace('\n', '')

for i in range(len(teams)):
    for j in range(len(teams)):
        if i == j: continue
            
        file_a, name_a = teams[i]
        file_b, name_b = teams[j]
        
        # Get match results for team a vs team b
        match_data_file_name = min(name_a, name_b) + '_vs_' + max(name_a, name_b) + '.dat'
        match_data_file = open(join(MATCH_RESULTS_DIR, match_data_file_name), 'r')
        outcomes = [process_raw_outcome(l) for l in match_data_file]
        match_data_file.close()
        
        # Get DataFrame props
        num_rows, num_cols = match_results_df.shape
        
        # Insert row if doesn't exist or reset row
        index = -1
        for i in range(num_rows):
            row = match_results_df.loc[i]
            if row.Team == name_a and row.Opponent == name_b:
                index = i
                break
        if index == -1:
            index = num_rows
        
        w, l, t, i = 0, 0, 0, 0
        for outcome in outcomes:
            if outcome == name_a:
                w += 1
            elif outcome == name_b:
                l += 1
            elif outcome == 'tied':
                t += 1
            elif outcome == 'invalid':
                i += 1
            else:
                raise Error('Invalid match outcome')
        match_results_df.loc[index] = [name_a, name_b, w, l, t, i]
# Out:
# 1 7 46
# 1 8 46
# 1 0 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 1 46
# 1 2 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46
# 1 7 46
# 1 8 46

# %%
match_results_df[match_results_df.Team == 'baselineTeam2_Rachel_Li']
# Out:
#                        Team                            Opponent Wins Losses  \
# 6   baselineTeam2_Rachel_Li  myTeam2_4foodNum_ALI_KHALEEL_AHMED    5      8
# 7   baselineTeam2_Rachel_Li  myTeam2_5foodNum_ALI_KHALEEL_AHMED    6      2
# 45  baselineTeam2_Rachel_Li                    PacBot_Kevin_Cao    3      9
# 56  baselineTeam2_Rachel_Li          baselineTeam2_Raghav_Anand    8      3
#
#    Ties Invalid
# 6     1       1
# 7     2       5
# 45    0       3
# 56    4       0

# %%
range(len(teams))
# Out:
# range(0, 46)
